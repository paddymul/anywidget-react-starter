# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from anyw2_react import Widget

# %%
# %%javascript
# console.clear()

# %%
Widget()
# Out:
# Widget()
